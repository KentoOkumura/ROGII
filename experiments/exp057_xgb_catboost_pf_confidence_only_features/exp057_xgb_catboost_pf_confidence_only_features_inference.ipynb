# %% [markdown]
# # exp057_xgb_catboost_pf_confidence_only_features inference
#
# This experiment is a train-side feature audit only.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. Inference status

# %% [markdown]
# ## 1. Setup and configuration

# %%
from settings import ExperimentPaths, load_config

paths = ExperimentPaths()
config = load_config()
print("Experiment:", config["experiment"]["name"])
print("Route:", config["experiment"]["route"])

# %% [markdown]
# ## 2. Inference status

# %%
raise SystemExit(
    "exp057 is an audit-only train experiment. "
    "Create an inference-port experiment only after a PF confidence candidate "
    "is supported by both original-fold and well-hash audits."
)
