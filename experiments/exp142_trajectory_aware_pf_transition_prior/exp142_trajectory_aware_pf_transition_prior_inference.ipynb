# %% [markdown]
# # exp142 trajectory-aware PF transition prior inference
#
# No inference candidate is selected. This notebook records that the experiment is train-side diagnostic only until trajectory-aware PF candidates demonstrate enough headroom and raw-test-compatible regeneration is implemented in the same experiment.

# %%
from settings import get_nested, load_config

config = load_config()
print('experiment:', get_nested(config, 'experiment.name'))
print('route:', get_nested(config, 'experiment.route'))
print('inference mode:', get_nested(config, 'inference.mode'))
print('selected candidate:', get_nested(config, 'inference.selected_candidate'))
print('notes:', get_nested(config, 'inference.notes'))
