# %% [markdown]
# # exp310_effective_sample_size_shrunk_sigma_gr inference
#
# Design-only fail-closed scaffold. Inference is outside the approved scope.

# %%
raise RuntimeError(
    "exp310 is a conditional train-side support audit; inference and submission are forbidden"
)

# %%
# This cell must never create predictions or submission.csv.
raise RuntimeError("exp310 inference is intentionally disabled")
