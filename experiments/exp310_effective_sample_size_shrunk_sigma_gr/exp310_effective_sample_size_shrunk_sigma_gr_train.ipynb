# %% [markdown]
# # exp310_effective_sample_size_shrunk_sigma_gr train
#
# Design-only scaffold. Support audit, trigger, shrinkage, and HMM logic are intentionally not implemented.

# %% [markdown]
# ## Dependency
#
# Blocked until exp307 passes; HMM remains blocked unless the frozen target-free trigger also passes.

# %%
raise RuntimeError(
    "exp310 is design-only and blocked on exp307 plus its target-free trigger"
)

# %%
# No support audit, trigger, HMM prediction, metrics, or output is produced.
raise RuntimeError("exp310 train implementation is intentionally absent")
