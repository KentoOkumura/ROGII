    'dXWUB3Mi9ne7Hx6HmmwDfrVafXbRzarhNSZHzp5HAbrHSI2ReY8yx6h43/UI70ARpEDZm+xw7d0d1smn+Pvzdqo6'
    'WpvrsOdw42QIbQiH3aWNkN1sR+OIbOViXaDdHHOhFWAzQCzl6/pgQ/Iigwiu64t1WlflPZqE7nC1L0Y7SSuyjkDG'
    'yarw/a7oAmO18Jrojg/Lz9EmBU0nDnl93oPVoXdPMHYs1qU4p6ObIBxj1CIdGDe3+08MD857tK+Aoejv+cbruu36'
    'c3Jbt4eszQOIenwoW/HhUOCZ1ZXY4NV1eO1NUckLmwK8K2PmQo25yykkuu7eXgb5z3jcggdE/7xIUW0X6h8YGfy7'
    'Huj3zfLDvlHrmAQb3viqfvGCK+gwQ2lXNap/TIIBIEYF257SgWqa0mt9KezdYIJTeXGS2VNMIKuLTMCgaBo6Q8RR'
    'CuKz/wdQSwECFAMUAAAACAAAACEAwkskNhUFAAAtDQAACwAAAAAAAAAAAAAAgAEAAAAAY29uZmlnLnlhbWxQSwEC'
    'FAMUAAAACAAAACEAPu7IkhECAAArBAAACwAAAAAAAAAAAAAAgAE+BQAAcHJvamVjdC55bWxQSwECFAMUAAAACAAA'
    'ACEAWXwNaVcBAAA3AgAACwAAAAAAAAAAAAAAgAF4BwAAc2V0dGluZ3MucHlQSwECFAMUAAAACAAAACEAessoBjEA'
    'AAAvAAAADwAAAAAAAAAAAAAAgAH4CAAAc3JjL19faW5pdF9fLnB5UEsBAhQDFAAAAAgAAAAhAG8EZ3SjAAAA6QAA'
    'AAwAAAAAAAAAAAAAAIABVgkAAHNyYy9wYXRocy5weVBLAQIUAxQAAAAIAAAAIQB0JQFK+BsAAHhnAAA2AAAAAAAA'
    'AAAAAACAASMKAAB0eXBld2VsbF9nZW9sb2d5X25laWdoYm9yX3ByaW9yX3BmX2xpa2VsaWhvb2RfcHJvYmUucHlQ'
    'SwUGAAAAAAYABgCGAQAAbyYAAAAA'
)
_KAGGLE_SUPPORT_MANIFEST = {
  "config.yaml": {
    "bytes": 3373,
    "sha256": "77eecb0024c41aebcab0f996dfdbe612332a0e9cdd3757aeac7b57bb3206a33b"
  },
  "project.yml": {
    "bytes": 1067,
    "sha256": "7c933e0240d1b4a8f66a4085bcb9b1eb97d9100f1ac494c8bb789219d39fe157"
  },
  "settings.py": {
    "bytes": 567,
    "sha256": "961722000818568be54afbbedb686ceef94b662cf208189912a49647241a4d57"
  },
  "src/__init__.py": {
    "bytes": 47,
    "sha256": "d531b37e210d810fc44638dd3bc6e6ffbf24223f9b1894c893f45a6ee4622e64"
  },
  "src/paths.py": {
    "bytes": 233,
    "sha256": "5aff21dc5fd8725576e38be7da9e222d25f2aa02237b8e445d2c240c53305436"
  },
  "typewell_geology_neighbor_prior_pf_likelihood_probe.py": {
    "bytes": 26488,
    "sha256": "3f7bf3e3f904b575bc01b43a0d64b84f1c7dd9adf76112d2c922497ebe290e07"
  }
}
_zip_bytes = _kaggle_base64.b64decode(_KAGGLE_SUPPORT_ZIP_B64)
with _kaggle_zipfile.ZipFile(_kaggle_io.BytesIO(_zip_bytes)) as _zip:
    for _member in _zip.infolist():
        _path = _KagglePath(_member.filename)
        if _path.is_absolute() or '..' in _path.parts:
            raise RuntimeError(f'unsafe bootstrap path: {_member.filename}')
    _zip.extractall('.')
for _relative_path, _info in _KAGGLE_SUPPORT_MANIFEST.items():
    _contents = _KagglePath(_relative_path).read_bytes()
    _digest = _kaggle_hashlib.sha256(_contents).hexdigest()
    if _digest != _info['sha256']:
        raise RuntimeError(f'bootstrap hash mismatch: {_relative_path}')
print(
    f"Prepared {len(_KAGGLE_SUPPORT_MANIFEST)} Kaggle support files "
    "from zip bootstrap."
)

# %% [markdown]
# # exp120 typewell geology neighbor prior PF likelihood probe
#
# Train-side diagnostic for `typewell_geology_neighbor_prior_pf_likelihood_probe`.
#
# This notebook evaluates typewell marker likelihood and native overlap neighbor drift likelihood on train pseudo-tail rows only. It does not create an inference candidate or submission.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. Input discovery
# 3. Fold-safe likelihood audit
# 4. Metrics and artifacts
# 5. Decision notes

# %% [markdown]
# ## 1. Setup and configuration

# %%
from pathlib import Path
import json
import pandas as pd

from settings import EXP_ID, EXP_DIR, default_output_dir, load_config
from typewell_geology_neighbor_prior_pf_likelihood_probe import resolve_inputs, run_audit

cfg = load_config()
out_dir = default_output_dir()
print('experiment:', EXP_ID)
print('route:', cfg['experiment']['route'])
print('status:', cfg['experiment']['status'])
print('parents:', cfg.get('lineage', {}).get('diagnostic_parents', []))
print('output_dir:', out_dir)

# %% [markdown]
# ## 2. Input discovery

# %%
inputs = resolve_inputs(cfg)
print('train_dir:', inputs.train_dir)
print('feature_cache:', inputs.feature_cache)
print('cluster_assignments:', inputs.cluster_assignments)

preview = pd.read_csv(inputs.feature_cache, nrows=5)
display(preview.head())
print('feature columns:', list(preview.columns)[:80])

# %% [markdown]
# ## 3. Fold-safe likelihood audit
#
# The audit builds neighbor drift priors from train-fold wells only. The validation fold true TVT is used only for scoring. Candidate TVT columns are treated as particle proxies because the original PF particle traces are not saved.

# %%
summary = run_audit(cfg, out_dir)
print(json.dumps(summary, indent=2, sort_keys=True))

# %% [markdown]
# ## 4. Metrics and artifacts

# %%
variant_path = Path(summary['outputs']['variant_metrics'])
bucket_path = Path(summary['outputs']['bucket_metrics'])
by_well_path = Path(summary['outputs']['by_well'])

variant_metrics = pd.read_csv(variant_path)
bucket_metrics = pd.read_csv(bucket_path)
by_well = pd.read_csv(by_well_path)

display(variant_metrics)
display(bucket_metrics.head(30))
display(by_well.sort_values('delta_vs_likpf_mean', ascending=False).head(20))

# %%
try:
    import matplotlib.pyplot as plt
    plot_df = variant_metrics.sort_values('rmse', ascending=True).head(12).iloc[::-1]
    ax = plot_df.plot.barh(x='variant', y='rmse', figsize=(9, 5), legend=False)
    ax.set_xlabel('RMSE')
    ax.set_title('exp120 variant RMSE')
    plt.tight_layout()
    plt.show()
except Exception as e:
    print('plot skipped:', repr(e))

# %% [markdown]
# ## 5. Decision notes

# %%
baseline = cfg['candidates']['baseline']
base_rmse = float(variant_metrics.loc[variant_metrics['variant'] == baseline, 'rmse'].iloc[0])
best = variant_metrics.iloc[0]
print('baseline:', baseline, base_rmse)
print('best:', best['variant'], float(best['rmse']), 'delta:', float(best['rmse']) - base_rmse)
print('neighbor_prior_valid_rate:', summary['neighbor_prior_valid_rate'])
print('marker_prior_valid_rate:', summary['marker_prior_valid_rate'])
print('decision:', summary['decision'])
