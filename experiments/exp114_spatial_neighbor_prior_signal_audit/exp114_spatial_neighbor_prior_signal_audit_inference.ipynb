# %% [markdown]
# # exp114_spatial_neighbor_prior_signal_audit inference
#
# No inference candidate is selected for this train-side diagnostic.

# %% [markdown]
# ## Contents
#
# 1. Setup and paths
# 2. No-submission guard

# %% [markdown]
# ## 1. Setup and paths

# %%
from __future__ import annotations

from settings import EXPERIMENT_NAME, ExperimentPaths, get_nested, load_config

paths = ExperimentPaths()
paths.require_kaggle_runtime()
paths.ensure_output_dirs()
config = load_config()

print("Experiment:", EXPERIMENT_NAME)
print("Inference mode:", get_nested(config, "inference.mode"))
print("Selected variant:", get_nested(config, "inference.selected_variant"))
print("Submission path would be:", paths.submission_path)

# %% [markdown]
# ## 2. No-submission guard

# %%
raise RuntimeError(
    "exp114 is a train-side spatial neighbor prior audit only. "
    "Run the train notebook and inspect candidate/signal metrics before creating any inference port."
)
