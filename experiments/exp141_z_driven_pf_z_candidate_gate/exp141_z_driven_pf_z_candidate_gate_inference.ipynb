# %% [markdown]
# # exp141_z_driven_pf_z_candidate_gate inference
#
# Train-side diagnostic only。train audit で採用判断が出るまで submission は生成しない。

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. Disabled inference marker

# %% [markdown]
# ## 1. Setup and configuration

# %%
from __future__ import annotations

import json

from settings import EXPERIMENT_NAME, ExperimentPaths, load_config
from z_driven_pf_z_candidate_gate import run_inference_from_config

paths = ExperimentPaths()
paths.require_kaggle_runtime()
paths.ensure_output_dirs()
config = load_config()

print('Experiment:', EXPERIMENT_NAME)
print('Inference mode:', config['inference']['mode'])
print('Artifacts:', paths.artifacts_dir)

# %% [markdown]
# ## 2. Disabled inference marker

# %%
summary = run_inference_from_config(config, output_dir=paths.artifacts_dir)
print(json.dumps(summary, indent=2))
