# %% [markdown]
# # exp134_self_gr_multiscale_longtail_gate inference
#
# Diagnostic-only experiment. This inference notebook intentionally does not generate `submission.csv`.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. No-submission decision

# %% [markdown]
# ## 1. Setup and configuration

# %%
from __future__ import annotations

import json

from settings import EXPERIMENT_NAME, ExperimentPaths, get_nested, load_config

paths = ExperimentPaths()
paths.require_kaggle_runtime()
paths.ensure_output_dirs()
config = load_config()

print("Experiment:", EXPERIMENT_NAME)
print("Route:", get_nested(config, "experiment.route"))
print("Inference mode:", get_nested(config, "inference.mode"))
print("Selected variant:", get_nested(config, "inference.selected_variant"))

# %% [markdown]
# ## 2. No-submission decision

# %%
summary = {
    "experiment": EXPERIMENT_NAME,
    "status": "no_submission_diagnostic_only",
    "reason": "self_gr_multiscale_longtail_gate is a train-side confidence diagnostic; any useful signal must move into a later exp092 add-only LightGBM or ranker ablation before inference.",
    "submission_created": False,
}
paths.metrics_path.write_text(json.dumps(summary, indent=2, ensure_ascii=False, sort_keys=True) + "\n")
print(json.dumps(summary, indent=2, ensure_ascii=False))
