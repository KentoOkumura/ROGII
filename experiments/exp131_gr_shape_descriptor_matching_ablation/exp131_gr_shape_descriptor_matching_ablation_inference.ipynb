# %% [markdown]
# # exp131_gr_shape_descriptor_matching_ablation inference
#
# This experiment is train-side diagnostic only and does not create `submission.csv`.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. No-op inference guard

# %% [markdown]
# ## 1. Setup and configuration

# %%
from __future__ import annotations

import json

from settings import EXPERIMENT_NAME, ExperimentPaths, get_nested, load_config

paths = ExperimentPaths()
paths.ensure_output_dirs()
config = load_config()

print(json.dumps({
    "experiment": EXPERIMENT_NAME,
    "route": get_nested(config, "experiment.route"),
    "status": get_nested(config, "experiment.status"),
    "parent": get_nested(config, "lineage.parent"),
    "inference_mode": get_nested(config, "inference.mode"),
    "selected_variant": get_nested(config, "inference.selected_variant"),
}, indent=2, ensure_ascii=False))

# %% [markdown]
# ## 2. No-op inference guard

# %%
notes = get_nested(config, "inference.notes") or []
print(json.dumps({
    "status": "no_submission_created",
    "reason": "train_side_gr_shape_descriptor_matching_ablation_only",
    "notes": notes,
}, indent=2, ensure_ascii=False))
