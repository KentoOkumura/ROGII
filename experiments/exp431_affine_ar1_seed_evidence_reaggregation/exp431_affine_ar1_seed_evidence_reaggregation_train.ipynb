# %% [markdown]
# # exp431 affine + AR(1) seed evidence reaggregation — closed
#
# exp427 version 2 は technical / scientific AND gate をともに FAIL しました。事前登録した no-rescue 分岐に従い、exp431 は未実装のまま terminal close しています。
#
# この notebook に実行コードはありません。正の閉鎖記録は `.steering/20260728-exp431-affine-ar1-seed-evidence-reaggregation/`、`config.yaml`、`result.md` を参照してください。
