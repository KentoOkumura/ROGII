# %% [markdown]
# # exp032_public_sel15_pf_residual_correction inference
#
# This experiment is an audit-only residual correction study and does not generate a submission.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. Inference policy

# %% [markdown]
# ## 1. Setup and configuration

# %%
from settings import EXPERIMENT_NAME, ExperimentPaths, get_nested, load_config

paths = ExperimentPaths()
config = load_config()

print("Experiment:", EXPERIMENT_NAME)
print("Route:", get_nested(config, "experiment.route"))
print("Status:", get_nested(config, "experiment.status"))

# %% [markdown]
# ## 2. Inference policy

# %%
raise RuntimeError(
    "exp032 is audit-only. If a residual correction candidate is supported, "
    "create a separate inference experiment that ports the selected correction "
    "into the exp027 public sel15 inference flow."
)
