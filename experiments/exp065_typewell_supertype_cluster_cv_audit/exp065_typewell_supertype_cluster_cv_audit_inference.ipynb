# %% [markdown]
# # exp065_typewell_supertype_cluster_cv_audit inference
#
# No submission is produced. This experiment discovers common typewell candidates only.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. No submission marker

# %% [markdown]
# ## 1. Setup and configuration

# %%
from __future__ import annotations

from settings import EXPERIMENT_NAME, ExperimentPaths, load_config

paths = ExperimentPaths()
paths.require_kaggle_runtime()
paths.ensure_output_dirs()
config = load_config()

print("Experiment:", EXPERIMENT_NAME)
print("Purpose:", config["experiment"]["description"])
print("Output root:", paths.output_root)

# %% [markdown]
# ## 2. No submission marker

# %%
marker = paths.output_root / "NO_SUBMISSION.txt"
marker.write_text("exp065 discovers common typewell groups only; no submission is produced.\n")
print("Wrote:", marker)
