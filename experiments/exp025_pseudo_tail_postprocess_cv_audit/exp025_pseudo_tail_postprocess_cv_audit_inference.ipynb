# %% [markdown]
# # exp025_pseudo_tail_postprocess_cv_audit inference
#
# This experiment is an OOF postprocess audit and intentionally does not generate a submission.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. Inference decision

# %% [markdown]
# ## 1. Setup and configuration

# %%
from pathlib import Path

from pseudo_tail_postprocess_cv_audit import get_nested, load_yaml

config = load_yaml(Path("config.yaml"))
print(f"Experiment: {config['experiment']['name']}")
print(f"Parent inference experiment: {get_nested(config, 'audit.parent_inference_experiment')}")

# %% [markdown]
# ## 2. Inference decision
#
# Postprocess inference should be implemented in a follow-up experiment only if the train audit shows fold-held improvement over raw pseudo-tail prediction.
