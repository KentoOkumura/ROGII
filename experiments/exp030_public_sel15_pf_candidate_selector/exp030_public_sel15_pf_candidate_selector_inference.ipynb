# %% [markdown]
# # exp030_public_sel15_pf_candidate_selector inference
#
# This experiment is an audit and does not produce a submission.

# %% [markdown]
# ## Contents
#
# 1. Setup and paths
# 2. No-op guard

# %% [markdown]
# ## 1. Setup and paths

# %%
from __future__ import annotations

from settings import EXPERIMENT_NAME, ExperimentPaths, get_nested, load_config

paths = ExperimentPaths()
config = load_config()

print("Experiment:", EXPERIMENT_NAME)
print("Route:", get_nested(config, "experiment.route"))
print("Artifacts:", paths.artifacts_dir)
print("Submission path:", paths.submission_path)

# %% [markdown]
# ## 2. No-op guard

# %%
raise RuntimeError("exp030 is a selector audit only. Do not submit this inference notebook.")
