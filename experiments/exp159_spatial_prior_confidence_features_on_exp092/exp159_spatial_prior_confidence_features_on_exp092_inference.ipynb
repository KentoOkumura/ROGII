# %% [markdown]
# # exp159_spatial_prior_confidence_features_on_exp092 inference
#
# Inference is intentionally disabled for this train-side feature audit.

# %% [markdown]
# ## Status

# %%
from settings import EXPERIMENT_NAME, get_nested, load_config

config = load_config()
print("Experiment:", EXPERIMENT_NAME)
print("Inference mode:", get_nested(config, "inference.mode"))
print("Selected variant:", get_nested(config, "inference.selected_variant"))
print("Notes:", get_nested(config, "inference.notes"))

# %% [markdown]
# Raw-test/full-train spatial prior feature parity is required before any inference port or submission.
