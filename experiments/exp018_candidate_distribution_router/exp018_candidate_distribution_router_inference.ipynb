# %% [markdown]
# # exp018_candidate_distribution_router inference
#
# This experiment is an OOF artifact audit and has no submission inference path.

# %%
print('exp018 is an OOF audit only; run the train notebook or audit_candidate_distribution_router.py')
