# %%
# Kaggle push sends only the notebook body, so recreate local support files first.
import base64 as _kaggle_base64
import hashlib as _kaggle_hashlib
import io as _kaggle_io
import zipfile as _kaggle_zipfile
from pathlib import Path as _KagglePath

_KAGGLE_SUPPORT_ZIP_B64 = (
    'UEsDBBQAAAAIAAAAIQDX9imqigcAAO4XAAALAAAAY29uZmlnLnlhbWzFWFmP2zgSfvevIOa5ZXc7OwniAQaYK7sD'
    '7BxIGvNK0BIlM5ZEgUcf8+vnK5KSKLe7EwdZ7Evi5lH8quqrS/JhkEZ1sne7FWO96OSOfSMfhpvta47/rt+8Cv+9'
    '3fKh5nspOj5Y6SvthGp5jX+8kbwTwze4XUlbGjU4pXsIuTVC9YVVlWTpHMM5VmvD/ny3+RGiNq06/vmOlaKvVCWc'
    'tAy/WOmNARz223+Z0d5JLJYHbSzTPXMHySKqTUTFIpqC4DDrTS1KuSYs4eqOdS3vdCVbrFgnnLc7prqhlaSwrHiv'
    'HTe+x25ppKAV4QB9e719XVy/Lrbfkig/VOe3Vq3qpWgkWW4QBHrHkrE8H4z+KEuyBS81NIo/K2VFY2R4n9e+bePr'
    'Vpa6r4R55FGOJZGMFUlZ3gyeGwmRlS/VXrXKPfLGC1NxmDM46PWrII5OteIxv709s89raEueK0V5kNnpt6/Iz5NH'
    'AP1OGqjIYfmeG9EfpeHCV8rNl26ub5aX0jEg6+/xVtkKa1WtpMGdyfoi2MNqb0r46WVyrQfSqFJ1za3vOthpx74P'
    'AN7L2oCzNjBDt9VIrQUvjG/BIgLNBHgBjtHp53i2DoJvD+OVj1r1NjmCGXEPmjtpOtUr61TJ/vjjHRuMrFRwsL1K'
    'DAAZ951y4E0R5T45GJ4RCUz0FCMXseiikyBJDmPBYVd0p6dwsnP0sNFXUXLOtCvQ0x1woHeq9yDPVXh478ujdEUr'
    '72TLpDEAaWSDZGDXAdD2DVMUdu0jE6yVjSgjsYBs8PsWyieope7AW2URoXthJYVFeAC3EWFBwUqJptfBYk6YRrr1'
    'anUnWkJO6SLEp4EWzeOOLfOOozzyDDFwrZPOqHLHTGflIpLixhRJGT3jSVrURpSt5Gf3kDWcCAt8/0iB6+BI/A5G'
    'O3smoCPyv3RoZPoiE7x8vpI9fj9/gZzLrZMDF3vLh7ff0r172bZLLe29cuWBI9/zm+vra270vQ0Wk9WO/WuLnw0C'
    'YUDMt75DBk8SLNKXDId3Y0LJM8kT9ySxrRRHShyDBlEeRy/82g/e5WGAiJTMzaXiJEpYbXQ3Bh9RKpJincQ9X0gg'
    'FRm9yu5v4zOLzLCIqlFo5Cd3d44I7K2sYgxQ5SJjqL5J0RICkFBFC08RmLHdjlJ/12zme0G2BR4v2e1ftyxgwa5P'
    'yMObTlPAIip86SjvFNDLjYiRZxpS9ApPM9XXEqmslLnlxndvDypkr1TlSaUsFkmx76ACxXBfwwEkJb0RnwgvWNmE'
    'y4htFDLS3APLXubFFDAoTeCKmeAWITM4tW9lhgGhDzMI4gQOgthmx2hhg7+wFhm1WN2ENdqD0NMtLBFNBUHhIe2i'
    'LcrMTc0rKdZTUlLiAgBQSwMEFAAAAAgAAAAhAG8EZ3SjAAAA6QAAAAwAAABzcmMvcGF0aHMucHldj70KgzAURvf7'
    'FCGTLpY+QAdbHTJoxFgolBJiG2nA/JDE0sdvFLo4fpxzD9zJW404n5a4eMk5UtpZH5EwxkYRlTUBYFodJ+J7VuNf'
    '6NIE6Ckd0GkbWYqoOSXywstg54/M8sIJL00M9+MDqnIoeUX6pG9XB4RfIgoM9a2re9LU7cB2XH6d9EqvBQwVvez5'
    'yz4TYNdzQxgjtN3zsIxahbA+geEHUEsBAhQDFAAAAAgAAAAhANf2KaqKBwAA7hcAAAsAAAAAAAAAAAAAAIABAAAA'
    'AGNvbmZpZy55YW1sUEsBAhQDFAAAAAgAAAAhAKPM6BHTHAAAQ3oAACEAAAAAAAAAAAAAAIABswcAAHBmX2JlYW1f'
    'cHNldWRvdGFpbF9mYWlsdXJlX21hcC5weVBLAQIUAxQAAAAIAAAAIQA+7siSEQIAACsEAAALAAAAAAAAAAAAAACA'
    'AcUkAABwcm9qZWN0LnltbFBLAQIUAxQAAAAIAAAAIQCQ5t8jxgkAAPooAAALAAAAAAAAAAAAAACAAf8mAABzZXR0'
    'aW5ncy5weVBLAQIUAxQAAAAIAAAAIQB6yygGMQAAAC8AAAAPAAAAAAAAAAAAAACAAe4wAABzcmMvX19pbml0X18u'
    'cHlQSwECFAMUAAAACAAAACEAbwRndKMAAADpAAAADAAAAAAAAAAAAAAAgAFMMQAAc3JjL3BhdGhzLnB5UEsFBgAA'
    'AAAGAAYAcQEAABkyAAAAAA=='
)
_KAGGLE_SUPPORT_MANIFEST = {
  "config.yaml": {
    "bytes": 6126,
    "sha256": "8a01c018f6003119ea83684e5aa3ef30977e1b548b2e6a90a4b0d0ef4e533eae"
  },
  "pf_beam_pseudotail_failure_map.py": {
    "bytes": 31299,
    "sha256": "ababa33e3bb5d9994244dc187a8d21fa81dfb28a474e736b1ba5f140d7ee9fa0"
  },
  "project.yml": {
    "bytes": 1067,
    "sha256": "7c933e0240d1b4a8f66a4085bcb9b1eb97d9100f1ac494c8bb789219d39fe157"
  },
  "settings.py": {
    "bytes": 10490,
    "sha256": "a2df0669499fa8a2c6403ef1af91bdce31ef63157ac4b59cc81f9489ac6855ed"
  },
  "src/__init__.py": {
    "bytes": 47,
    "sha256": "d531b37e210d810fc44638dd3bc6e6ffbf24223f9b1894c893f45a6ee4622e64"
  },
  "src/paths.py": {
    "bytes": 233,
    "sha256": "5aff21dc5fd8725576e38be7da9e222d25f2aa02237b8e445d2c240c53305436"
  }
}
_zip_bytes = _kaggle_base64.b64decode(_KAGGLE_SUPPORT_ZIP_B64)
with _kaggle_zipfile.ZipFile(_kaggle_io.BytesIO(_zip_bytes)) as _zip:
    for _member in _zip.infolist():
        _path = _KagglePath(_member.filename)
        if _path.is_absolute() or '..' in _path.parts:
            raise RuntimeError(f'unsafe bootstrap path: {_member.filename}')
    _zip.extractall('.')
for _relative_path, _info in _KAGGLE_SUPPORT_MANIFEST.items():
    _contents = _KagglePath(_relative_path).read_bytes()
    _digest = _kaggle_hashlib.sha256(_contents).hexdigest()
    if _digest != _info['sha256']:
        raise RuntimeError(f'bootstrap hash mismatch: {_relative_path}')
print(
    f"Prepared {len(_KAGGLE_SUPPORT_MANIFEST)} Kaggle support files "
    "from zip bootstrap."
)

# %% [markdown]
# # exp126_exp073_exp092_pf_beam_pseudotail_failure_map train
#
# Train-side diagnostic failure map for current ML route anchors (`exp073` / `exp092`) and PF/Beam/likPF candidates.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. Input availability
# 3. Build failure map
# 4. Metrics and artifacts

# %% [markdown]
# ## 1. Setup and configuration

# %%
from pathlib import Path
import json
import pandas as pd

from settings import ExperimentPaths, get_nested
from pf_beam_pseudotail_failure_map import (
    EXP072_FEATURES,
    EXP073_PREDICTIONS,
    EXP092_PREDICTIONS,
    OUTPUT_PREFIX,
    find_input_file,
    run_train_from_config,
)

paths = ExperimentPaths()
paths.require_kaggle_runtime()
paths.ensure_output_dirs()
config = paths.config

print("experiment:", get_nested(config, "experiment.name"))
print("route:", get_nested(config, "experiment.route"))
print("parent:", get_nested(config, "lineage.parent"))
print("output dir:", paths.artifacts_dir)
print("train dir:", paths.train_data_dir)

# %%
display(pd.DataFrame({
    "key": [
        "exp073_model",
        "exp092_model",
        "exp092_reference_model",
        "audit_mode",
        "max_prediction_rows",
        "max_feature_rows",
    ],
    "value": [
        get_nested(config, "model.exp073_model"),
        get_nested(config, "model.exp092_model"),
        get_nested(config, "model.exp092_reference_model"),
        get_nested(config, "audit.mode"),
        get_nested(config, "audit.max_prediction_rows"),
        get_nested(config, "audit.max_feature_rows"),
    ],
}))

# %% [markdown]
# ## 2. Input availability

# %%
input_specs = [
    ("exp072_feature_cache", EXP072_FEATURES, get_nested(config, "data.exp072_feature_cache")),
    ("exp073_predictions", EXP073_PREDICTIONS, get_nested(config, "data.exp073_predictions")),
    ("exp092_predictions", EXP092_PREDICTIONS, get_nested(config, "data.exp092_predictions")),
]
rows = []
for label, filename, configured in input_specs:
    path = find_input_file(filename, configured)
    rows.append({
        "label": label,
        "filename": filename,
        "path": str(path),
        "size_mb": path.stat().st_size / 1024 / 1024,
    })
display(pd.DataFrame(rows))

# %% [markdown]
# ## 3. Build failure map

# %%
summary = run_train_from_config(config, output_dir=paths.artifacts_dir)
print(json.dumps(summary["overall"], indent=2, sort_keys=True))
print("outputs:")
for name, rel in summary["outputs"].items():
    print(f"- {name}: {paths.artifacts_dir / rel}")

# %% [markdown]
# ## 4. Metrics and artifacts

# %%
candidate_metrics = pd.read_csv(paths.artifacts_dir / f"{OUTPUT_PREFIX}_candidate_metrics.csv")
bucket_metrics = pd.read_csv(paths.artifacts_dir / f"{OUTPUT_PREFIX}_bucket_metrics.csv")
well_metrics = pd.read_csv(paths.artifacts_dir / f"{OUTPUT_PREFIX}_well_metrics.csv")
summary_path = paths.artifacts_dir / f"{OUTPUT_PREFIX}_summary.json"

print("summary:", summary_path)
print("artifact README:", paths.artifacts_dir / "README.md")
display(candidate_metrics)
display(bucket_metrics.sort_values("exp092_lgb1_delta_vs_exp073", ascending=False).head(20))
display(well_metrics.head(20))
