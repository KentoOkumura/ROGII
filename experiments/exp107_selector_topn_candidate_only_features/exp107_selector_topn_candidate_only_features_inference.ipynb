# %% [markdown]
# # exp107_selector_topn_candidate_only_features inference
#
# This experiment is a train-side top-n candidate-only feature audit. Inference is intentionally disabled until the Kaggle train OOF review selects a variant.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. Disabled inference guard

# %% [markdown]
# ## 1. Setup and configuration

# %%
from settings import EXPERIMENT_NAME, ExperimentPaths, get_nested, load_config

paths = ExperimentPaths()
paths.require_kaggle_runtime()
config = load_config()

print("Experiment:", EXPERIMENT_NAME)
print("Inference mode:", get_nested(config, "inference.mode"))
print("Selected variant placeholder:", get_nested(config, "inference.selected_variant"))
print("Artifacts:", paths.artifacts_dir)

# %% [markdown]
# ## 2. Disabled inference guard

# %%
raise RuntimeError(
    "exp107 is train-side only. Run Kaggle train first, review top1/top2/top3 OOF, "
    "then implement an inference port only if a variant is selected."
)
