# %% [markdown]
# # exp047_gate_w030_inference_port_audit train
#
# This experiment has no standalone training run. The inference notebook fits the exp026-style anchor and applies the fixed exp047 gate w=0.30 to hidden test wells before producing `submission.csv` and audit files.

# %%
raise RuntimeError(
    'exp047_gate_w030_inference_port_audit is an inference-port audit. Prepare and run the inference notebook on Kaggle instead.'
)
