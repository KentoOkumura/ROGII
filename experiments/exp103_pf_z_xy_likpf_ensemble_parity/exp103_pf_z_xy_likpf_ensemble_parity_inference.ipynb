# %% [markdown]
# # exp103 inference
#
# No inference candidate is selected. This experiment is a train-side parity audit for `xy_likpf_*` versus exp072 `pf_z` / `likpf_*` candidates.

# %%
from settings import get_nested, load_config

config = load_config()
print('experiment:', get_nested(config, 'experiment.name'))
print('inference mode:', get_nested(config, 'inference.mode'))
print('selected candidate:', get_nested(config, 'inference.selected_candidate'))
assert get_nested(config, 'inference.selected_candidate') is None
