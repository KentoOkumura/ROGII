# %% [markdown]
# # exp112 inference
#
# ## Contents
#
# 1. Setup
# 2. Inference policy

# %% [markdown]
# ## 1. Setup

# %%
from settings import get_nested, load_config

config = load_config()
print('experiment:', get_nested(config, 'experiment.name'))
print('route:', get_nested(config, 'experiment.route'))
print('inference mode:', get_nested(config, 'inference.mode'))

# %% [markdown]
# ## 2. Inference policy

# %%
print('No submission.csv is generated for exp112.')
print('This experiment is a train-side posthoc audit and ML feature cache producer only.')
print('Raw-test parity is required before any PF-weight, verifier, or ML-feature submission work.')
