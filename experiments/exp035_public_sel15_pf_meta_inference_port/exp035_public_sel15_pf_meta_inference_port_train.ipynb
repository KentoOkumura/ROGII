# %% [markdown]
# # exp035_public_sel15_pf_meta_inference_port train
#
# This experiment has no standalone training run. The inference notebook fits the exp034-selected Ridge meta residual model from the exp029 pseudo-hidden feature artifact and an exp026-style pseudo-tail anchor before producing `submission.csv`.

# %% [markdown]
# raise RuntimeError(
#     'exp035 is an inference-port experiment. Prepare and run the inference notebook on Kaggle instead.'
# )
