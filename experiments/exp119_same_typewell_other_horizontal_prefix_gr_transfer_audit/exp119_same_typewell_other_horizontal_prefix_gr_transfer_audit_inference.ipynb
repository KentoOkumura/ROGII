# %% [markdown]
# # exp119_same_typewell_other_horizontal_prefix_gr_transfer_audit inference
#
# Inference is intentionally not selected for this train-side leakage and signal audit.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. Inference decision

# %% [markdown]
# ## 1. Setup and configuration

# %%
from settings import EXPERIMENT_NAME, ExperimentPaths, get_nested, load_config

paths = ExperimentPaths()
config = load_config()

print("Experiment:", EXPERIMENT_NAME)
print("Route:", get_nested(config, "experiment.route"))
print("Inference mode:", get_nested(config, "inference.mode"))
print("Selected variant:", get_nested(config, "inference.selected_variant"))
print("Artifacts:", paths.artifacts_dir)

# %% [markdown]
# ## 2. Inference decision

# %%
mode = get_nested(config, "inference.mode")
if mode != "not_selected_train_side_audit_only":
    raise RuntimeError(f"Unexpected inference mode for exp118: {mode}")

print("No submission.csv is generated by exp118.")
print("A separate raw-test/rules parity experiment is required before inference porting.")
