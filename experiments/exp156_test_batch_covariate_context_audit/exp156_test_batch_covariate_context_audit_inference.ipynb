# %% [markdown]
# # exp156_test_batch_covariate_context_audit inference guard
#
# この実験は train-side posthoc audit 専用。submission.csv は生成しない。

# %%
import json

from settings import ExperimentPaths, load_config
from test_batch_covariate_context_audit import OUTPUT_PREFIX, run_inference_from_config

paths = ExperimentPaths()
config = load_config()
summary = run_inference_from_config(config, output_dir=paths.artifacts_dir)
print(json.dumps(summary, indent=2))
print('No submission.csv is generated for', OUTPUT_PREFIX)
