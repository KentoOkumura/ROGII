# %% [markdown]
# # exp041_ravaghi_beam_exact_feature_ablation inference
#
# This experiment is a train-side feature audit only.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. Inference status

# %% [markdown]
# ## 1. Setup and configuration

# %%
from settings import ExperimentPaths, load_config

paths = ExperimentPaths()
config = load_config()
print("Experiment:", config["experiment"]["name"])
print("Route:", config["experiment"]["route"])

# %% [markdown]
# ## 2. Inference status

# %%
raise SystemExit(
    "exp041 is an audit-only train experiment. "
    "Create a separate inference-port experiment only after a single-LGBM feature candidate "
    "is supported by both original-fold and well-hash audits."
)
