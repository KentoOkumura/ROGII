# %% [markdown]
# # exp243 PF seed medoids — shard 2
#
# Canonical exp243 train notebookをdeterministic well shard 2で実行するentrypoint。

# %%
import os

os.environ["EXP243_ACTIVE_WELL_SHARD_INDEX"] = "2"

import exp243_pf_seed_medoids_train  # noqa: F401, E402
