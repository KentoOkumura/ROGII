# %% [markdown]
# # exp115_hidden_like_spatial_holdout_from_ppt inference
#
# This experiment is a train-side holdout audit. It does not create a submission.

# %% [markdown]
# ## Contents
#
# 1. Setup and paths
# 2. Inference status

# %% [markdown]
# ## 1. Setup and paths

# %%
from __future__ import annotations

from settings import EXPERIMENT_NAME, ExperimentPaths, get_nested, load_config

paths = ExperimentPaths()
paths.require_kaggle_runtime()
paths.ensure_output_dirs()
config = load_config()

print('Experiment:', EXPERIMENT_NAME)
print('Route:', get_nested(config, 'experiment.route'))
print('Inference mode:', get_nested(config, 'inference.mode'))
print('Artifacts directory:', paths.artifacts_dir)

# %% [markdown]
# ## 2. Inference status

# %%
print('No inference or submission is selected for exp115.')
print('Run the train notebook to generate holdout_wells and fold_assignments artifacts.')
