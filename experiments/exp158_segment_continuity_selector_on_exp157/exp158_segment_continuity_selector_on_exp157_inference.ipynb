# %% [markdown]
# # exp158 inference
#
# この実験は train-side posthoc audit 専用。`segment_continuity_selector_on_exp157` は提出候補を生成しない。

# %% [markdown]
# ## Status
#
# Viterbi selector が OOF、worst-well、near-row、hidden-like stress、raw-test parity を通過するまで inference port は作らない。

# %%
from settings import get_nested, load_config

config = load_config()
print('experiment:', get_nested(config, 'experiment.name'))
print('inference mode:', get_nested(config, 'inference.mode'))
print('selected variant:', get_nested(config, 'inference.selected_variant'))
print('notes:')
for note in get_nested(config, 'inference.notes'):
    print(' -', note)
