# %% [markdown]
# # exp410 PF mechanism counterfactual — shard 2
#
# Runs the preregistered initialization, transition, GR, resampling, and
# roughening interventions on the fixed sentinel wells assigned to shard 2.

# %%
import os

os.environ["EXP410_COUNTERFACTUAL_SHARD_INDEX"] = "2"

import run_counterfactual_sentinels  # noqa: E402,F401
