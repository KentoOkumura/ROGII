# %% [markdown]
# # exp093_pf_candidate_coverage_then_ranker_audit inference
#
# This experiment is a train-side diagnostic only.

# %% [markdown]
# ## 1. Setup and status

# %%
from __future__ import annotations

import json
from datetime import UTC, datetime

from settings import EXPERIMENT_NAME, ExperimentPaths, get_nested, load_config

paths = ExperimentPaths()
config = load_config()
status = {
    "experiment": EXPERIMENT_NAME,
    "route": get_nested(config, "experiment.route"),
    "inference_mode": get_nested(config, "inference.mode"),
    "selected_variant": get_nested(config, "inference.selected_variant"),
    "updated_at": datetime.now(UTC).isoformat(),
    "notes": get_nested(config, "inference.notes"),
}
print(json.dumps(status, indent=2, ensure_ascii=False))
