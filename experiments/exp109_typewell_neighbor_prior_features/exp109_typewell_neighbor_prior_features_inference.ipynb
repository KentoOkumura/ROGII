# %% [markdown]
# # exp109_typewell_neighbor_prior_features inference
#
# This experiment is a train-side audit only. No inference candidate is selected.

# %%
from settings import EXPERIMENT_NAME, ExperimentPaths, get_nested, load_config

paths = ExperimentPaths()
paths.require_kaggle_runtime()
config = load_config()

print("Experiment:", EXPERIMENT_NAME)
print("Inference mode:", get_nested(config, "inference.mode"))
raise SystemExit("exp109 is train-side audit only; no submission.csv is generated.")
