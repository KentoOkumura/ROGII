# %% [markdown]
# # exp108_topn_related_feature_prune inference
#
# This experiment is a train-side feature-prune audit. Inference is intentionally disabled until a prune variant is selected from Kaggle train OOF review.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. Disabled guard

# %% [markdown]
# ## 1. Setup and configuration

# %%
from __future__ import annotations

from settings import EXPERIMENT_NAME, ExperimentPaths, get_nested, load_config

paths = ExperimentPaths()
paths.require_kaggle_runtime()
config = load_config()

print("Experiment:", EXPERIMENT_NAME)
print("Inference mode:", get_nested(config, "inference.mode"))
print("Selected variant:", get_nested(config, "inference.selected_variant"))

# %% [markdown]
# ## 2. Disabled guard

# %%
raise RuntimeError(
    "exp108 is train-side only. Run Kaggle train first and review OOF, worst-well, "
    "distance bucket, feature importance, and path continuity before enabling inference."
)
