# %% [markdown]
# # exp150_formation_physical_imputer_revisit inference
#
# This experiment is a train-side fold-safe audit. It intentionally does not generate `submission.csv`.

# %% [markdown]
# ## 1. Setup and configuration

# %%
from settings import ExperimentPaths

paths = ExperimentPaths()
config = paths.config

print('experiment:', config['experiment']['name'])
print('route:', config['experiment']['route'])
print('status:', config['experiment']['status'])
print('reason: fold-safe formation physical imputer audit only; no submission candidate')

# %% [markdown]
# ## 2. No-op inference

# %%
print('No inference output is written for exp150.')
