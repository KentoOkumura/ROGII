# %% [markdown]
# # exp122_exact_override_negative_control inference
#
# この実験は submission を作らない診断専用 audit。inference notebook は Kaggle 上で同じ監査を再実行し、train output と同じ形式の metrics / artifacts を保存するための入口。

# %% [markdown]
# ## Contents
#
# 1. Setup
# 2. Audit run
# 3. Output check

# %% [markdown]
# ## 1. Setup

# %%
from __future__ import annotations

import json

from exact_override_negative_control import run_audit
from settings import EXPERIMENT_NAME, ExperimentPaths, get_nested, load_config

paths = ExperimentPaths()
paths.require_kaggle_runtime()
paths.ensure_output_dirs()
config = load_config()

print("Experiment:", EXPERIMENT_NAME)
print("Route:", get_nested(config, "experiment.route"))
print("Artifacts:", paths.artifacts_dir)

# %% [markdown]
# ## 2. Audit run

# %%
summary = run_audit(paths=paths, config=config)
print(json.dumps(summary["decision"], indent=2, sort_keys=True))

# %% [markdown]
# ## 3. Output check

# %%
metrics = json.loads(paths.metrics_path.read_text())
print("metrics_path:", paths.metrics_path)
print("status:", metrics["status"])
for label, path in metrics["artifacts"].items():
    print(label, path)
