# %% [markdown]
# # exp072_exp063_full_replay_feature_cache inference
#
# No-op notebook. Test PF/Beam/likelihood-PF features should be regenerated inside each downstream experiment's inference notebook using current raw test files.

# %% [markdown]
# ## 1. Setup and policy check

# %%
from settings import ExperimentPaths, load_config, get_nested

paths = ExperimentPaths()
paths.ensure_output_dirs()
config = load_config()

print("Experiment:", config["experiment"]["name"])
print("Inference mode:", get_nested(config, "inference.mode"))
print("Policy: no test feature cache is generated by exp072.")
print("Downstream inference notebooks must regenerate current raw test PF/Beam features directly.")
