# %% [markdown]
# # exp496 exp486 absolute geometry fixed13 selector inference
#
# Design-only placeholder. current-test候補生成、推論、submissionは未承認です。
#
# Train-side scientific AND gateを通過し、別の設計・実装承認を得るまで
# 実行セルを追加しません。
