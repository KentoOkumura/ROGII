# %% [markdown]
# # exp091_self_gr_likelihood_pf_beam_probe inference
#
# This experiment is a train-side PF/Beam candidate coverage audit. Inference is intentionally disabled until coverage, rank headroom, and bucket miss rates justify a follow-up selector.

# %%
from settings import load_config, get_nested

config = load_config()
print("Experiment:", config["experiment"]["name"])
print("Route:", config["experiment"]["route"])
print("Inference mode:", get_nested(config, "inference.mode"))
print("Selected variant:", get_nested(config, "inference.selected_variant"))
raise RuntimeError("exp091 is diagnostic-only; implement a follow-up ranker/selector before inference.")
