# %% [markdown]
# # exp304_gr_denoiser_emission_separability_readout inference
#
# Design-only placeholder. Inference and submission are disabled.

# %%
raise RuntimeError(
    "exp304 inference/submission is disabled by the design-only contract."
)
