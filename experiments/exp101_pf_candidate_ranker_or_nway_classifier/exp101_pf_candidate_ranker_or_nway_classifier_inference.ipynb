# %% [markdown]
# # exp101_pf_candidate_ranker_or_nway_classifier inference
#
# This experiment is a train-side candidate selector audit only. No inference candidate or submission is selected here.

# %%
from settings import get_nested, load_config

config = load_config()
print('experiment:', get_nested(config, 'experiment.name'))
print('inference mode:', get_nested(config, 'inference.mode'))
print('selected variant:', get_nested(config, 'inference.selected_variant'))
raise SystemExit('exp101 is train-side audit only; no inference notebook run is expected.')
