# %% [markdown]
# # exp087_prefix_backtest_tvt_confidence inference
#
# No-op inference notebook for a diagnostic-only prefix-backtest confidence audit.

# %% [markdown]
# ## 1. Setup and policy check

# %%
from __future__ import annotations

from settings import EXPERIMENT_NAME, ExperimentPaths, get_nested, load_config

paths = ExperimentPaths()
paths.require_kaggle_runtime()
config = load_config()

print("Experiment:", EXPERIMENT_NAME)
print("Route:", get_nested(config, "experiment.route"))
print("Status:", get_nested(config, "experiment.status"))
print("Audit mode:", get_nested(config, "audit.mode"))
print("Submission policy: no submission.csv is produced by this diagnostic experiment.")
