# %% [markdown]
# # exp047 public PF/Beam gate-only audit inference
#
# ## Contents
#
# 1. Setup and guard
# 2. No submission output

# %% [markdown]
# ## 1. Setup and guard
#
# This experiment is audit-only. Inference is intentionally disabled until the gate-only train-side surrogate metrics are reviewed.

# %%
from settings import EXPERIMENT_NAME, ExperimentPaths, load_config

paths = ExperimentPaths()
config = load_config()
print('experiment:', EXPERIMENT_NAME)
print('route:', config.get('experiment', {}).get('route'))
print('audit-only: no submission.csv will be generated')

# %% [markdown]
# ## 2. No submission output

# %%
paths.ensure_output_dirs()
marker = paths.artifacts_dir / 'NO_SUBMISSION.txt'
marker.write_text('exp047 is audit-only; no submission.csv is generated.\n')
print(marker)
