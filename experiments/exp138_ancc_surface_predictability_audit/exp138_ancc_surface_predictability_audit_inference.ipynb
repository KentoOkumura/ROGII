# %% [markdown]
# # exp138_ancc_surface_predictability_audit inference
#
# This experiment is a train-side ANCC surface audit and does not generate a submission.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. Audit status

# %% [markdown]
# ## 1. Setup and configuration

# %%
from __future__ import annotations

import json

from settings import EXPERIMENT_NAME, ExperimentPaths, load_config

paths = ExperimentPaths()
paths.require_kaggle_runtime()
paths.ensure_output_dirs()
config = load_config()

print("Experiment:", EXPERIMENT_NAME)
print("Route:", config.get("experiment", {}).get("route"))
print("Submission target:", None)
print("Reason: ANCC surface predictability audit only")

# %% [markdown]
# ## 2. Audit status

# %%
if paths.metrics_path.exists():
    metrics = json.loads(paths.metrics_path.read_text())
    print(json.dumps(metrics.get("best_by_delta_rmse", {}), indent=2))
else:
    print("Train audit metrics are not present in this Kaggle working directory.")

print("No submission.csv is written by design.")
