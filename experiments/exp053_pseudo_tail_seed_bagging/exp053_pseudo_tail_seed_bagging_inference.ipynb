# %% [markdown]
# # exp053_pseudo_tail_seed_bagging inference
#
# This diagnostic experiment does not create a submission until Kaggle train CV shows a reliable seed-bagging improvement.

# %%
raise RuntimeError('exp053 is a train-side diagnostic experiment and has no inference submission yet.')
