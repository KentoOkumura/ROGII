# %% [markdown]
# # exp436_sparse_global_stratigraphic_potential inference
#
# Design-only placeholder. Inference and submission are disabled and have not been implemented.
#
# Inference remains blocked until the corrected six-surface Stage 0--2 promotion gates pass and separate approval is given.
