# %% [markdown]
# # exp054_pseudo_tail_seed_bagging_inference_submit train
#
# This experiment ports the exp051 selected LightGBM capacity pseudo-tail candidate. The authoritative train/CV result is exp051 fixed bucket shrink CV 12.634392.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. Audit reference

# %% [markdown]
# ## 1. Setup and configuration

# %%
from pathlib import Path

from pseudo_tail_augmentation import get_nested, load_yaml

config = load_yaml(Path("config.yaml"))
print(f"Experiment: {config['experiment']['name']}")
print(f"Parent postprocess audit: {get_nested(config, 'audit.parent_postprocess_audit')}")
print(f"Selected postprocess CV: {get_nested(config, 'audit.selected_postprocess_cv')}")
print(f"Selected method: {get_nested(config, 'postprocess.selected_method')}")

# %% [markdown]
# ## 2. Audit reference
#
# The inference notebook fits the final model and writes `submission.csv`. This train notebook is intentionally not pushed as the primary run for exp052.
