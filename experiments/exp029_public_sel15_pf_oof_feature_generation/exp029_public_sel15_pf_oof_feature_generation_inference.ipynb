# %% [markdown]
# # exp029_public_sel15_pf_oof_feature_generation inference
#
# This experiment is train-side feature generation only. It does not create a competition submission.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. Inference policy

# %% [markdown]
# ## 1. Setup and configuration

# %%
from settings import EXPERIMENT_NAME, ExperimentPaths, get_nested, load_config

paths = ExperimentPaths()
config = load_config()

print(f"Experiment: {EXPERIMENT_NAME}")
print(f"Route: {get_nested(config, 'experiment.route')}")
print(f"Status: {get_nested(config, 'experiment.status')}")
print(f"Feature output schema: {get_nested(config, 'model.output_schema')}")

# %% [markdown]
# ## 2. Inference policy

# %%
raise RuntimeError(
    'exp029 is not an inference/submission experiment. Run the train notebook to generate '
    'public_sel15_pf_oof_features.csv, then use a separate selector or meta-stack experiment.'
)
