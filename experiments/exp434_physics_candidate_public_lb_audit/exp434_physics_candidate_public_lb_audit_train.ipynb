# %% [markdown]
# # exp434_physics_candidate_public_lb_audit train
#
# Design-only placeholder. This experiment trains no model and does not regenerate OOF.

# %% [markdown]
# ## Status
#
# Implementation and execution are not approved. See the steering documents and `config.yaml`.
