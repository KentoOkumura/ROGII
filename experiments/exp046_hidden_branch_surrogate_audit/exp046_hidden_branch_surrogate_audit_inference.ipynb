# %% [markdown]
# # exp046 hidden branch surrogate audit inference
#
# ## Contents
#
# 1. Setup and guard
# 2. No submission output

# %% [markdown]
# ## 1. Setup and guard
#
# This experiment is audit-only. Inference is intentionally disabled because hidden branch surrogate metrics must be reviewed before any code submission experiment is created.

# %%
from pathlib import Path

from settings import EXPERIMENT_NAME, ExperimentPaths, load_config

paths = ExperimentPaths()
config = load_config()
print('experiment:', EXPERIMENT_NAME)
print('route:', config.get('experiment', {}).get('route'))
print('audit-only: no submission.csv will be generated')

# %% [markdown]
# ## 2. No submission output

# %%
paths.ensure_output_dirs()
marker = paths.artifacts_dir / 'NO_SUBMISSION.txt'
marker.write_text('exp046 is audit-only; no submission.csv is generated.
')
print(marker)
