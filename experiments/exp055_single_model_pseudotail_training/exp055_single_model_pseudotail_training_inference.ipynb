# %% [markdown]
# # exp055_single_model_pseudotail_training inference
#
# This experiment is a train-side feature audit only.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. Inference status

# %% [markdown]
# ## 1. Setup and configuration

# %%
from settings import ExperimentPaths, load_config

paths = ExperimentPaths()
config = load_config()
print("Experiment:", config["experiment"]["name"])
print("Route:", config["experiment"]["route"])

# %% [markdown]
# ## 2. Inference status

# %%
raise SystemExit(
    "exp055 is an audit-only train experiment. "
    "Create an inference-port experiment only after the pseudo-tail training policy "
    "is supported by both original-fold and well-hash audits."
)
