# %% [markdown]
# # exp083_pf_beam_true_tvt_2d_well_eda inference
#
# No submission is produced. This experiment is a train-side visual EDA notebook.

# %% [markdown]
# ## Contents
#
# 1. Setup
# 2. No-op policy check

# %% [markdown]
# ## 1. Setup

# %%
from __future__ import annotations

import json
from datetime import UTC, datetime

from settings import EXPERIMENT_NAME, ExperimentPaths, get_nested, load_config

paths = ExperimentPaths()
paths.require_kaggle_runtime()
paths.ensure_output_dirs()
config = load_config()

print("Experiment:", EXPERIMENT_NAME)
print("Route:", get_nested(config, "experiment.route"))
print("Inference mode: not applicable")

# %% [markdown]
# ## 2. No-op policy check

# %%
metrics = {
    "experiment": EXPERIMENT_NAME,
    "status": "inference_not_applicable_visual_eda_only",
    "created_at": datetime.now(UTC).isoformat(),
    "cv": None,
    "public_lb": None,
    "private_lb": None,
    "notes": "This experiment generates train-side EDA plots only and does not create submission.csv.",
}
paths.metrics_path.write_text(json.dumps(metrics, indent=2, sort_keys=True) + "\n")
print(json.dumps(metrics, indent=2, sort_keys=True))
