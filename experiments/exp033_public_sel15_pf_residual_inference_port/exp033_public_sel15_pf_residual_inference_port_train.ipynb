# %% [markdown]
# # exp033_public_sel15_pf_residual_inference_port train
#
# This experiment has no standalone training run. The inference notebook fits the selected Ridge residual model from the exp029 pseudo-hidden feature artifact before producing `submission.csv`.

# %% [markdown]
# ## Notes
#
# - Supporting CV evidence is recorded in `exp032_public_sel15_pf_residual_correction`.
# - Kaggle execution for this experiment should use the inference notebook.
