# %% [markdown]
# # exp049_xgboost_pseudo_tail_residual inference
#
# This diagnostic experiment does not create a submission until Kaggle train CV shows a reliable improvement.

# %%
raise RuntimeError('exp049 is a train-side diagnostic experiment and has no inference submission yet.')
