# %% [markdown]
# # exp034_public_sel15_pf_meta_stack inference
#
# This experiment is train-audit only. Inference porting requires a supported candidate from the train notebook.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. Porting gate

# %% [markdown]
# ## 1. Setup and configuration

# %%
from settings import EXPERIMENT_NAME, get_nested, load_config

config = load_config()
print("Experiment:", EXPERIMENT_NAME)
print("Route:", get_nested(config, "experiment.route"))
print("Status:", get_nested(config, "experiment.status"))

# %% [markdown]
# ## 2. Porting gate

# %%
raise RuntimeError(
    "exp034 is an audit-only train experiment. "
    "Create a separate inference-port experiment only after meta_stack_supported is true."
)
