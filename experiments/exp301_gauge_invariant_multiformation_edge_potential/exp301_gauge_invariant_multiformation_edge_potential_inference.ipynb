# %% [markdown]
# # exp301_gauge_invariant_multiformation_edge_potential inference
#
# Design-only fail-closed placeholder. Inference and submission are not authorized.

# %%
raise RuntimeError(
    "exp301 inference is disabled until Stage 0/1 PASS and separate user approval."
)
