# %% [markdown]
# # exp144_learned_likelihood_hidden_stress_and_rawtest_parity inference
#
# この実験は readout 専用で、submission.csv は生成しない。

# %%
from settings import get_nested, load_config
config = load_config()
print("experiment:", get_nested(config, "experiment.name"))
print("inference mode:", get_nested(config, "inference.mode"))
print("selected variant:", get_nested(config, "inference.selected_variant"))

# %%
print("No submission.csv is generated for exp144.")
print("Use train/readout artifacts to decide whether exp127 learned likelihood features can be reused as diagnostics.")
