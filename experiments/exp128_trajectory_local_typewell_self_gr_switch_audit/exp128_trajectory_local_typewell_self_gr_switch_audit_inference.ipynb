# %% [markdown]
# # exp128_trajectory_local_typewell_self_gr_switch_audit inference
#
# This experiment is a train-side diagnostic audit. It intentionally has no inference port or submission candidate.

# %% [markdown]
# ## Contents
#
# 1. Setup and configuration
# 2. Inference status

# %% [markdown]
# ## 1. Setup and configuration

# %%
import json
from settings import ExperimentPaths, load_config

paths = ExperimentPaths()
config = load_config()
print('experiment:', config['experiment']['name'])
print('route:', config['experiment']['route'])
print('inference mode:', config['inference']['mode'])
print('selected variant:', config['inference']['selected_variant'])

# %% [markdown]
# ## 2. Inference status

# %%
raise RuntimeError(
    'exp128 is train-side audit only. Run the train notebook on Kaggle and inspect metrics before creating any raw-test parity or inference port.'
)
