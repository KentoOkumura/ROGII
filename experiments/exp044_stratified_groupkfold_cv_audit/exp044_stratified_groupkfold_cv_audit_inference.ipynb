# %% [markdown]
# # exp044_stratified_groupkfold_cv_audit inference
#
# This diagnostic experiment has no inference or submission candidate.

# %% [markdown]
# ## Contents
#
# 1. Setup and paths
# 2. No-submission marker

# %% [markdown]
# ## 1. Setup and paths

# %%
from __future__ import annotations

import os
from datetime import UTC, datetime

from settings import EXPERIMENT_NAME, ExperimentPaths

DEBUG = os.environ.get("EXPERIMENT_DEBUG", "0") == "1"

paths = ExperimentPaths()
paths.require_kaggle_runtime()
paths.ensure_output_dirs()

print("Experiment:", EXPERIMENT_NAME)
print("Artifacts:", paths.artifacts_dir)
print("Debug:", DEBUG)

# %% [markdown]
# ## 2. No-submission marker

# %%
marker = paths.artifacts_dir / "NO_SUBMISSION.txt"
marker.write_text(
    f"{EXPERIMENT_NAME} is a diagnostic CV audit and does not create submission.csv.\n"
    f"written_at={datetime.now(UTC).isoformat()}\n"
)
print("No submission is generated for this experiment.")
print("Marker:", marker)
