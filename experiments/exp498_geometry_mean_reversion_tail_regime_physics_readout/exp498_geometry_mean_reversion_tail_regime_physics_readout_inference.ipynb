# %% [markdown]
# # exp498_geometry_mean_reversion_tail_regime_physics_readout inference
#
# Inference is disabled and out of scope for this diagnostic experiment.
#
# This notebook intentionally contains no executable cells.
