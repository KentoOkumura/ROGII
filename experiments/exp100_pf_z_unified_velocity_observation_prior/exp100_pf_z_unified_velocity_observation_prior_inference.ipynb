# %% [markdown]
# # exp100 inference
#
# This experiment is train-side PF z-prior ablation only. No inference candidate or submission is produced.

# %%
from settings import get_nested, load_config

config = load_config()
print('experiment:', get_nested(config, 'experiment.name'))
print('inference mode:', get_nested(config, 'inference.mode'))
print('selected variant:', get_nested(config, 'inference.selected_variant'))
assert get_nested(config, 'inference.selected_variant') is None
print('No inference output is expected for exp100.')
