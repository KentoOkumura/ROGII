# %% [markdown]
# # exp019_pf_beam_candidate_quality_audit train
#
# PF/beam candidate quality audit entrypoint. This notebook is intended to run on Kaggle.

# %%
from audit_pf_beam_candidate_quality import main

main()
