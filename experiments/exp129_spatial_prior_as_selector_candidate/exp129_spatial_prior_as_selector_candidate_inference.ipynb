# %% [markdown]
# # exp129_spatial_prior_as_selector_candidate inference
#
# This experiment is train-side diagnostic only and does not create `submission.csv`.

# %% [markdown]
# ## Status

# %%
from settings import get_nested, load_config

config = load_config()
print('experiment:', get_nested(config, 'experiment.name'))
print('route:', get_nested(config, 'experiment.route'))
print('inference mode:', get_nested(config, 'inference.mode'))
print('selected_variant:', get_nested(config, 'inference.selected_variant'))
raise RuntimeError('exp129 is a train-side selector audit only; no inference/submission is selected.')
