# %% [markdown]
# # exp123_cross_test_prefix_label_context_audit inference guard
#
# この実験は train-side 診断専用で、他 well の visible `TVT_input` label 利用には rules risk がある。推論 notebook は提出を生成しない。

# %% [markdown]
# ## Contents
#
# 1. Setup and guard

# %% [markdown]
# ## 1. Setup and guard

# %%
from __future__ import annotations

from settings import EXPERIMENT_NAME, ExperimentPaths, get_nested, load_config

paths = ExperimentPaths()
config = load_config()

print("Experiment:", EXPERIMENT_NAME)
print("Route:", get_nested(config, "experiment.route"))
print("Status:", get_nested(config, "experiment.status"))
print("Submission path would be:", paths.submission_path)

raise RuntimeError(
    "exp123 is a train-side rules-risk diagnostic. It intentionally does not create "
    "submission.csv. Confirm organizer rules and implement a separate guarded policy "
    "inside this same experiment before any inference run."
)
