# %% [markdown]
# # exp037 inference guard
#
# This experiment is an audit. It should not create `submission.csv` until online training is selected from held-out evidence and ported deliberately.

# %% [markdown]
# ## 1. Setup and configuration

# %%
from settings import load_config

config = load_config()
print('Experiment:', config['experiment']['name'])
print('Status:', config['experiment']['status'])
print('Parent:', config['lineage']['parent'])
print('Selected method is not decided before train audit output is reviewed.')

# %% [markdown]
# ## 2. Submission guard

# %%
raise RuntimeError(
    'exp037_test_time_prefix_online_training_audit is audit-only. '
    'Run the train audit and port a supported method before preparing inference.'
)
